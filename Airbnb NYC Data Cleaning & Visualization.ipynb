# %% [markdown]
# Your task is to clean the provided Airbnb NYC dataset and perform data analysis using Pandas. Read all instructions carefully.
#
# What you have to do:
#
# 1. Handle missing / NaN values
#    - Find all missing values in the dataset.
#    - Fill NaN values using a proper strategy (mean, median, mode, or a suitable placeholder depending on the column). Explain why you chose that method.
#
# 2. Handle duplicate values
#    - Detect duplicate rows in the dataset.
#    - Remove all duplicates.
#
# 3. Detect outliers
#    - Identify outliers in the numeric columns (for example: price, minimum_nights, availability_365).
#    - Show them using a method of your choice (IQR, boxplot, etc.) and handle them appropriately.
#
# 4. Fix data types
#    - Some columns have the wrong data type (for example, price is stored as text). Convert them to the correct type.
#
# 5. Convert discrete values into continuous
#    - Where required, convert discrete values into continuous values.
#
# 6. Visualization (plots)
#    - Create proper plots/graphs for your cleaned data (missing values heatmap, price distribution, room type counts, neighbourhood group analysis, etc.).
#
# 7. Final verification (very important)
#    - At the END of your file, use df.info() and df.isnull().sum() to show that the data is now fully cleaned and has no missing values left.
#
# ⚠️ IMPORTANT RULES:
# - Use of AI is NOT allowed. If anyone uses AI to write their code, the assignment will be REJECTED with zero marks.
# - Write all the code yourself. You must be able to explain every line.
#
# Best of luck. Do your own work and learn properly. 💪
#
# Due Date : 16 July

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("airbnb.csv")

# %%
data.sample(10)
# Out:
#        id                      name host_id host_name neighbourhood_group  \
# 695   673            Beautiful loft   45217     James           Brooklyn
# 402   264             Modern studio   13499      John               bronx
# 508   222            Spacious 2BR     87430      Lisa       Staten island
# 172    44  Cozy apartment near park   61552     Maria       Staten island
# 1038  538        Quiet private room   43317     David            BROOKLYN
# 891   952            Beautiful loft   49030       NaN           Brooklyn
# 112   412        Quiet private room   90201     Sarah       Staten island
# 807   349             Modern studio   16167      Emma       Staten Island
# 912   722                       NaN    7553      Lisa           The Bronx
# 428   907  Cozy apartment near park   27812      Lisa       Staten Island
#
#            neighbourhood  latitude  longitude        room_type  price  \
# 695   Bedford-Stuyvesant  40.88831  -73.93774     PRIVATE ROOM    351
# ...

# %%
data.isna().sum()
# Out:
# id                                  0
# name                              271
# host_id                             0
# host_name                         127
# neighbourhood_group                 0
# neighbourhood                       5
# latitude                            5
# longitude                           0
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                        13
# reviews_per_month                  54
# calculated_host_listings_count      1
# availability_365                    0
# dtype: int64

# %%
data["name"].fillna("Unknown",inplace=True)
# Mein ne ise "unknown" se fill kiya because we have a 271 NAN agar mein isko drop krdeta
# to name wala pura row drop hojata jabke un rows me others data bhi mojood hain
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\1928504383.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["name"].fillna("Unknown",inplace=True)

# %%
data["host_name"].fillna("unknown",inplace=True)
# same uper wale ki tarha isko bhi fill kiya
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\1037391876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["host_name"].fillna("unknown",inplace=True)

# %%
data
# Out:
#        id                      name host_id host_name neighbourhood_group  \
# 0      10            Spacious 2BR     75847     Maria            brooklyn
# 1     286  Cozy apartment near park   84558     Chris       staten island
# 2     675  Cozy apartment near park   20892    Daniel              QUEENS
# 3     100  Cozy apartment near park   90224      Anna               BRONX
# 4     668                   Unknown   35757      John              QUEENS
# ...   ...                       ...     ...       ...                 ...
# 1035  920                   Unknown   35854    Robert               BRONX
# 1036  212        Quiet private room   32502      John           The Bronx
# 1037  503            Beautiful loft   43343    Daniel              QUEENS
# 1038  538        Quiet private room   43317     David            BROOKLYN
# 1039  176            Spacious 2BR     69495      Anna              Queens
#
#            neighbourhood  latitude  longitude        room_type  price  \
# ...

# %%
data.isna().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      5
# latitude                           5
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                       13
# reviews_per_month                 54
# calculated_host_listings_count     1
# availability_365                   0
# dtype: int64

# %%
data.isna().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      5
# latitude                           5
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                       13
# reviews_per_month                 54
# calculated_host_listings_count     1
# availability_365                   0
# dtype: int64

# %%
data["neighbourhood"].fillna(data.neighbourhood.mode()[0],inplace=True)
# Mein ne ise Mode se isliye fill kiya because ye aik categorial type hai
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\2797734895.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["neighbourhood"].fillna(data.neighbourhood.mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           5
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                       13
# reviews_per_month                 54
# calculated_host_listings_count     1
# availability_365                   0
# dtype: int64

# %%
data["last_review"]=data["last_review"].fillna("No review")
# Yhan last review ko "No review" se fill isliye kiya because data se decision liya jata hai to ye fake data dene se better hai

# %%
data.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           5
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                 54
# calculated_host_listings_count     1
# availability_365                   0
# dtype: int64

# %%
data["reviews_per_month"].fillna(data.mode,inplace=True)
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\1583915424.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["reviews_per_month"].fillna(data.mode,inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data["calculated_host_listings_count"]=data["calculated_host_listings_count"].fillna(data["calculated_host_listings_count"].mode()[0])

# %%
data["latitude"].fillna(data["latitude"].mode()[0],inplace=True)
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\1120367671.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["latitude"].fillna(data["latitude"].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    1
# availability_365                  0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(31)

# %%
data.drop_duplicates(inplace=True)

# %%
data["price"] = data["price"].str.replace("$", "")
data["price"] = data["price"].str.replace(",", "")
data["price"] = pd.to_numeric(data["price"], errors="coerce")

# %%
data.price.dtype
# Out:
# dtype('float64')

# %%
data["price"].fillna(data["price"].median(),inplace=True)
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_5440\3177134820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["price"].fillna(data["price"].median(),inplace=True)

# %%
data["price"]=data["price"].astype(int)

# %%
Q1 = data["price"].quantile(0.25)
Q3 = data["price"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

price_outliers = data[(data["price"] < lower) | (data["price"] > upper)]

# %%
data['price'] = np.where(data['price'] > upper, upper, data['price'])
data['price'] = np.where(data['price'] < lower, lower, data['price'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.price.max()
# Out:
# 741.0

# %%
data.price.min()
# Out:
# -219.0

# %%
data["price"].quantile(0.25)
# Out:
# np.float64(141.0)

# %%
data.host_id=data.host_id.str.replace('lalsa','0001')
data.host_id=data.host_id.str.replace('jdhja','0002')
data.host_id=data.host_id.str.replace('???','0003')

# %%
data.host_id=data.host_id.astype(float)

# %%
data.longitude=data.longitude.str.replace('???','0.004')
data.longitude=data.longitude.str.replace('haha','0.005')

# %%
data.longitude=data.longitude.astype(float)

# %%
data["minimum_nights"] = pd.to_numeric(data["minimum_nights"], errors="coerce")
data["minimum_nights"] = data["minimum_nights"].fillna(
    data["minimum_nights"].median())

data["minimum_nights"] = data["minimum_nights"].astype(int)

# %%
data["number_of_reviews"] = pd.to_numeric(data["number_of_reviews"], errors="coerce")

data["number_of_reviews"] = data["number_of_reviews"].fillna(
    data["number_of_reviews"].mode()[0]
)

data["number_of_reviews"] = data["number_of_reviews"].astype(int)

# %%
data["reviews_per_month"] = pd.to_numeric(
    data["reviews_per_month"],
    errors="coerce"
)

data["reviews_per_month"] = data["reviews_per_month"].fillna(
    data["reviews_per_month"].median()
)

# %%
data.sample(20)
# Out:
#        id                            name  host_id host_name  \
# 595   816                  Spacious 2BR     9048.0    Robert
# 128   563  Sunny room in the heart of NYC  97029.0   unknown
# 744   407              Quiet private room  77830.0    Daniel
# 137   495  Sunny room in the heart of NYC  49380.0     Sofia
# 300   900                   Modern studio  49062.0    Daniel
# 799   991              Quiet private room  29837.0     Sarah
# 1002  401                  Spacious 2BR    29256.0      John
# 678   228                  Spacious 2BR    16403.0   unknown
# 568   188  Sunny room in the heart of NYC  84151.0      Emma
# 89    516                         Unknown  24628.0    Daniel
# 24    479  Sunny room in the heart of NYC  96676.0     David
# 23    636                  Beautiful loft   4875.0      Anna
# 401   968                  Spacious 2BR    92154.0    Robert
# 918   679                   Modern studio  10227.0      John
# ...

# %%
data["calculated_host_listings_count"]=pd.to_numeric(data["calculated_host_listings_count"],errors="coerce")

data["calculated_host_listings_count"] = data["calculated_host_listings_count"].fillna(
    data["calculated_host_listings_count"].median())


data["calculated_host_listings_count"]=data["calculated_host_listings_count"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1040 non-null   int64
#  1   name                            1040 non-null   object
#  2   host_id                         1040 non-null   float64
#  3   host_name                       1040 non-null   object
#  4   neighbourhood_group             1040 non-null   object
#  5   neighbourhood                   1040 non-null   object
#  6   latitude                        1040 non-null   float64
#  7   longitude                       1040 non-null   float64
#  8   room_type                       1040 non-null   object
#  9   price                           1040 non-null   float64
#  10  minimum_nights                  1040 non-null   int64
#  11  number_of_reviews               1040 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x=data["price"])
plt.show()

# %%
data["room_type"].value_counts()

data["room_type"].value_counts().plot(kind="bar",color="skyblue")

plt.title("Room Type Counts")
plt.xlabel("Room Type")
plt.ylabel("Count")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1009 entries, 0 to 1039
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1009 non-null   int64
#  1   name                            1009 non-null   object
#  2   host_id                         1009 non-null   float64
#  3   host_name                       1009 non-null   object
#  4   neighbourhood_group             1009 non-null   object
#  5   neighbourhood                   1009 non-null   object
#  6   latitude                        1009 non-null   float64
#  7   longitude                       1009 non-null   float64
#  8   room_type                       1009 non-null   object
#  9   price                           1009 non-null   float64
#  10  minimum_nights                  1009 non-null   int64
#  11  number_of_reviews               1009 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
