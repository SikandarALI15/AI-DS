# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df=sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop(["sibsp","embarked","pclass","adult_male","deck","alone"],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    survived     sex   age  parch     fare   class    who  embark_town alive
# 0         0    male  22.0      0   7.2500   Third    man  Southampton    no
# 1         1  female  38.0      0  71.2833   First  woman    Cherbourg   yes
# 2         1  female  26.0      0   7.9250   Third  woman  Southampton   yes
# 3         1  female  35.0      0  53.1000   First  woman  Southampton   yes
# 4         0    male  35.0      0   8.0500   Third    man  Southampton    no
# 5         0    male   NaN      0   8.4583   Third    man   Queenstown    no
# 6         0    male  54.0      0  51.8625   First    man  Southampton    no
# 7         0    male   2.0      1  21.0750   Third  child  Southampton    no
# 8         1  female  27.0      2  11.1333   Third  woman  Southampton   yes
# 9         1  female  14.0      0  30.0708  Second  child    Cherbourg   yes

# %%
df.embark_town.value_counts()
# Out:
# embark_town
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: count, dtype: int64

# %%
df.rename(columns={"sex":"gender"},inplace=True)

# %%
df.head(5)
# Out:
#    survived  gender   age  parch     fare  class    who  embark_town alive
# 0         0    male  22.0      0   7.2500  Third    man  Southampton    no
# 1         1  female  38.0      0  71.2833  First  woman    Cherbourg   yes
# 2         1  female  26.0      0   7.9250  Third  woman  Southampton   yes
# 3         1  female  35.0      0  53.1000  First  woman  Southampton   yes
# 4         0    male  35.0      0   8.0500  Third    man  Southampton    no

# %% [markdown]
# # Barplot

# %%
X=df.gender.value_counts().index

# %%
Y=df.gender.value_counts()

# %%
sns.barplot(x=X,y=Y,palette=["r","g"])
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_704\2570142107.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=X,y=Y,palette=["r","g"])
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# # Histplot

# %%
df.age.fillna(df.age.median(),inplace=True)

# %%
sns.histplot(df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df.age, kde=True, color="y")
plt.show()

# %%
df.parch.value_counts()
# Out:
# parch
# 0    580
# 1    114
# 2     75
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df["class"].value_counts()
# Out:
# class
# Third     405
# First     214
# Second    165
# Name: count, dtype: int64

# %%
sns.countplot(x=df["class"],palette=["r","g","b"])
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_704\2844635669.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["class"],palette=["r","g","b"])
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x=df["class"],palette="rainbow")
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_704\1226161741.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["class"],palette="rainbow")
# <Axes: xlabel='class', ylabel='count'>

# %%
plt.title("Class count")
sns.countplot(x=df["class"],palette="rainbow")
plt.xlabel("Classes name")
plt.ylabel("Count of classes")
plt.show()
# Out:
# C:\Users\hafiz\AppData\Local\Temp\ipykernel_704\3418657166.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["class"],palette="rainbow")

# %%
df.embark_town.value_counts()
# Out:
# embark_town
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: count, dtype: int64

# %% [markdown]
# # Pipeplot

# %%
X=df.embark_town.value_counts()
Y=df.embark_town.value_counts().index

# %%
plt.pie(x=X,)
# Out:
# ([<matplotlib.patches.Wedge at 0x237584ede80>,
# ...
#  [Text(-0.7179148808490451, 0.8334255958725421, ''),
#   Text(0.5021437432169686, -0.9786989634959522, ''),
#   Text(1.069244779319076, -0.25829363503365854, '')])

# %%
# plt.title("Pie Chart of Embark Town", fontdict={"size": 15, "color": "green"})

# plt.pie(
#     x=X,
#     labels=Y,
#     autopct="%.2f%%",
#     colors=["y", "g", "b"]
# )

# plt.show()

# %%
plt.title("Pie Chart of Embark Town", fontdict={"size": 15, "color": "green"})
plt.pie(x=X,labels=Y,autopct="%.2f%%", colors=["y", "g", "b"])

plt.show()

# %% [markdown]
# # Ploting using pandas

# %%
df.embark_town.value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='embark_town'>

# %%
df.embark_town.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='embark_town'>

# %%
df.embark_town.value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
sns.boxplot(df.age)
# Out:
# <Axes: ylabel='age'>
