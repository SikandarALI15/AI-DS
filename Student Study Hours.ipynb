# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df=pd.read_csv("Students-Remarks.csv")

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
x=df[["Hours"]]
y=df[["Scores"]]

# %%
linear_pipeline = Pipeline([
    ('model', LinearRegression())
])

poly_pipeline = Pipeline([
    ('poly', PolynomialFeatures(degree=2)),
    ('model', LinearRegression())
])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=42,test_size=0.2)

# %%
linear_pipeline.fit(x_train, y_train)
lin_pred = linear_pipeline.predict(x_test)
print("Linear R2 Score:", r2_score(y_test, lin_pred))

poly_pipeline.fit(x_train, y_train)
poly_pred = poly_pipeline.predict(x_test)
print("Polynomial R2 Score:", r2_score(y_test, poly_pred))
# Out:
# Linear R2 Score: 0.9678055545167994
# Polynomial R2 Score: 0.9641965165901754

# %%
def predict_score(hours):
    
    input_data = pd.DataFrame([[hours]], columns=["Hours"])
    predicted_score = linear_pipeline.predict(input_data)[0][0]
    return f"{hours} , {predicted_score:.2f}"

print(predict_score(9.25))
# Out:
# 9.25 , 92.39
